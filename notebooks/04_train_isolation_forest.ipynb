# %% [markdown]
# # Train Isolation Forest on the custom dataset
#
# Fixes the bug from the original notebook (Isolation Forest doesn't accept
# `max_depth` or `min_samples_split`) and trains the supported configuration.

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from src.models.trainer import train_custom_pipeline

# %%
result = train_custom_pipeline()
result['isolation_forest']

# %%
result['rule_based']

# %%
result['mcnemar']
