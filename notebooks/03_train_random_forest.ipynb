# %% [markdown]
# # Train Random Forest on PaySim
#
# Wraps `src.models.trainer.train_paysim_pipeline` so the notebook stays thin and
# the heavy lifting lives in version-controlled modules. Outputs are saved to
# `models_local/` and can be pushed to HF Hub with `scripts/train_all.py` afterwards.

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from src.models.trainer import train_paysim_pipeline

# %%
# Subsample for speed during exploration; remove sample_n for full training
result = train_paysim_pipeline(sample_n=500_000)
result['rf']

# %%
result['rule_based']

# %%
result['mcnemar']

# %%
import pandas as pd
pd.Series(result['feature_importances']).sort_values(ascending=False)
