# %% [markdown]
# # Custom dataset EDA (51k rows, device + location features)
#
# Cleaned-up version of `isoforest.ipynb`. Re-uses `src` modules.

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from src.data.loader import load_custom, summarize
from src.data.feature_engineering import custom_features

sns.set_theme(style='whitegrid')

# %%
df = load_custom()
summarize(df, 'Custom')

# %%
df.isna().sum()

# %%
df.groupby('Device_Used')['Fraudulent'].mean().sort_values(ascending=False)

# %%
df.groupby('Location')['Fraudulent'].mean().sort_values(ascending=False)

# %%
df.groupby('Payment_Method')['Fraudulent'].mean().sort_values(ascending=False)

# %%
engineered = custom_features(df)
engineered.head()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='Fraudulent', y='Transaction_Amount')
plt.title('Transaction amount distribution: legit vs fraud')
plt.show()
